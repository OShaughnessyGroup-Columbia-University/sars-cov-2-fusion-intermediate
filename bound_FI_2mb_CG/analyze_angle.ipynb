# %%
import mdtraj as md
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits import mplot3d
import statsmodels.api as sm
from matplotlib import animation
from IPython.display import HTML
import matplotlib
from scipy.interpolate import interp1d
from scipy import interpolate

# %%
plt.rcParams['font.family'] = "Helvetica"
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['axes.labelsize'] = 28
plt.rcParams['xtick.labelsize'] = 28
plt.rcParams['ytick.labelsize'] = 28
plt.rcParams['xtick.major.width'] = 2
plt.rcParams['ytick.major.width'] = 2

# %%
dict15 = np.load('sep15/coordinate_15.npy', allow_pickle=True).item()
angle15 = dict15['angle2']
dict25 = np.load('sep25/coordinate_25.npy', allow_pickle=True).item()
angle25 = dict25['angle2']
dict20 = np.load('../20apr21_fi_captured/coordinate_20.npy', allow_pickle=True).item()
angle20 = dict20['angle2']

# %%
plt.figure(figsize=(10,6))
plt.hist(angle15, bins=np.linspace(0,90,31), density=True, alpha=0.7, label='15 nm')
plt.hist(angle20, bins=np.linspace(0,90,31), density=True, alpha=0.7, label='20 nm')
plt.hist(angle25, bins=np.linspace(0,90,31), density=True, alpha=0.7, label='25 nm')
plt.yticks([0,0.05,0.1])
plt.xlabel('backbone angle (degrees)')
plt.ylabel('pdf')
plt.legend(fontsize=20)
plt.xlim([0,90])
plt.ylim([0,0.1])
# Out:
# (0.0, 0.1)

# %%
print(len(angle15), len(angle20), len(angle25))
# Out:
# 4501 4501 4002
